# %%
import tensorflow as tf
from tensorflow import keras

# %%
print("Number of GPUS : ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Number of GPUS :  1

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))     # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data('chest_xray/chest_xray/train')
test = get_data('chest_xray/chest_xray/test')
val = get_data('chest_xray/chest_xray/val')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_17384/3742747629.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
pneumonia = os.listdir("chest_xray/train/PNEUMONIA")
pneumonia_dir = "chest_xray/train/PNEUMONIA"

plt.figure(figsize=(20, 10))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(pneumonia_dir, pneumonia[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title("Pneumonic X-Ray") 
   
plt.tight_layout()

# %%
normal = os.listdir("chest_xray/train/NORMAL")
normal_dir = "chest_xray/train/NORMAL"

plt.figure(figsize=(20, 10))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(normal_dir, normal[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title("Normal X-Ray") 
   
plt.tight_layout()

# %%
Path = 'chest_xray/'

# %%
x_train = []
y_train = []

x_test = []
y_test = []

x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in test:
  x_test.append(feature)
  y_test.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

# %%
print("Number of images in training dataset : {}".format(len(y_train)))
print("Number of images in test dataset : {}".format(len(y_test)))
print("Number of images in validation dataset : {}".format(len(y_val)))
# Out:
# Number of images in training dataset : 5216
# Number of images in test dataset : 624
# Number of images in validation dataset : 16

# %%
positives=[]
negatives=[]

for i in range(len(y_train)):
  if y_train[i]:
    positives.append(x_train[i])
  else:
    negatives.append(x_train[i])



plt.bar(labels,[len(negatives) , len(positives)], color=["red" , "green"])
plt.title("Total number of data in training dataset")
plt.ylabel('count')
plt.show()
print("Total: {}" .format( len(y_train)) )
print("Pneumonic: {}" .format( len(negatives)) )
print("Normal: {}" .format( len(positives)) )
# Out:
# Total: 5216
# Pneumonic: 3875
# Normal: 1341

# %% [markdown]
# Normalise Dataset

# %%
x_train = np.array(x_train)/255
x_val = np.array(x_val)/255
x_test = np.array(x_test)/255

# %%
x_train = x_train.reshape(-1,img_size,img_size , 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1,img_size,img_size , 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1,img_size,img_size , 1)
y_test = np.array(y_test)

# %%
y_train = y_train.reshape(-1,1)
y_val = y_val.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=30,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(x_train)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3) , strides = 1 , padding = 'same' , activation='relu' , input_shape=(150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding='same'))

model.add(Conv2D(64, (3,3) , strides = 1 , padding = 'same' , activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding='same'))

model.add(Conv2D(64,(3,3) , strides = 1 , padding = 'same' , activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding='same'))

model.add(Conv2D(128,(3,3) , strides = 1 , padding = 'same' , activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding='same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 38, 38, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 38, 38, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 19, 19, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1638528
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,769,409
# Trainable params: 1,768,833
# Non-trainable params: 576
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam' 
              , loss = 'binary_crossentropy' , 
              metrics = ['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.3,
                              patience=2,
                              min_lr=0.00000001, 
                              verbose=1)

# %%
r = model.fit(datagen.flow(x_train , y_train , batch_size=32),epochs = 50, validation_data = (x_val , y_val),callbacks = [reduce_lr])
# Out:
# Epoch 1/50
# 163/163 [==============================] - 22s 71ms/step - loss: 0.3772 - accuracy: 0.8748 - val_loss: 8.7162 - val_accuracy: 0.5000A: 10s - loss: 1.
# Epoch 2/50
# 163/163 [==============================] - 11s 65ms/step - loss: 0.2234 - accuracy: 0.9130 - val_loss: 11.0996 - val_accuracy: 0.5000
# Epoch 3/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1866 - accuracy: 0.9271 - val_loss: 5.9966 - val_accuracy: 0.5000
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 4/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1585 - accuracy: 0.9394 - val_loss: 2.2931 - val_accuracy: 0.5000
# Epoch 5/50
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1398 - accuracy: 0.9482 - val_loss: 1.8679 - val_accuracy: 0.5625
# Epoch 6/50
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1401 - accuracy: 0.9471 - val_loss: 1.8786 - val_accuracy: 0.5000
# Epoch 7/50
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1370 - accuracy: 0.9526 - val_loss: 2.7414 - val_accuracy: 0.5000
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 8/50
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1223 - accuracy: 0.9515 - val_loss: 0.5124 - val_accuracy: 0.8125
# Epoch 9/50
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1101 - accuracy: 0.9592 - val_loss: 0.8748 - val_accuracy: 0.6250
# Epoch 10/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1120 - accuracy: 0.9584 - val_loss: 2.4532 - val_accuracy: 0.5000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1046 - accuracy: 0.9638 - val_loss: 0.4675 - val_accuracy: 0.81250 - ac
# Epoch 42/50
# 163/163 [==============================] - 10s 64ms/step - loss: 0.0991 - accuracy: 0.9682 - val_loss: 0.4671 - val_accuracy: 0.8125
# Epoch 43/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.0978 - accuracy: 0.9668 - val_loss: 0.4777 - val_accuracy: 0.8125
# Epoch 44/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1057 - accuracy: 0.9645 - val_loss: 0.4682 - val_accuracy: 0.8125
# Epoch 45/50
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1040 - accuracy: 0.9628 - val_loss: 0.4664 - val_accuracy: 0.8125
# Epoch 46/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.0947 - accuracy: 0.9643 - val_loss: 0.4719 - val_accuracy: 0.8125
# Epoch 47/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.0889 - accuracy: 0.9699 - val_loss: 0.4646 - val_accuracy: 0.8125: 0s - loss: 0.089
# Epoch 48/50
# 163/163 [==============================] - 10s 63ms/step - loss: 0.0926 - accuracy: 0.9651 - val_loss: 0.4640 - val_accuracy: 0.8125926 -
# Epoch 49/50
# 163/163 [==============================] - 10s 64ms/step - loss: 0.0974 - accuracy: 0.9666 - val_loss: 0.4685 - val_accuracy: 0.8125
# Epoch 50/50
# 163/163 [==============================] - 10s 64ms/step - loss: 0.0981 - accuracy: 0.9640 - val_loss: 0.4621 - val_accuracy: 0.8125 loss: - ETA: 3s - los

# %%
print("Loss of the model on test data = ", model.evaluate(x_test,y_test)[0])
print("Accuracy of the model on test data is = ", model.evaluate(x_test,y_test)[1]*100,"%")
# Out:
# 20/20 [==============================] - 1s 18ms/step - loss: 0.2444 - accuracy: 0.9087
# Loss of the model on test data =  0.24443161487579346
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2444 - accuracy: 0.9087
# Accuracy of the model on test data is =  90.86538553237915 %

# %%
epochs = list(range(50))
fig , ax = plt.subplots(1,2)
train_acc = r.history['accuracy']
train_loss = r.history['loss']
val_acc = r.history['val_accuracy']
val_loss = r.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs, train_acc , 'go-' ,label='Training Accuracy')
ax[0].plot(epochs, val_acc ,'ro-' , label='Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

ax[1].plot(epochs, train_loss ,'go-' , label='Training Loss')
ax[1].plot(epochs, val_loss ,'ro-' , label='Validation Loss')
ax[1].legend()
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training and Validation Loss')

plt.show()

# %%
preds = model.predict(x_test)
Pneumonic=[]
Normal=[]
for i in range(len(preds)):
  if preds[i]>0.5:
    preds[i]=1
    Pneumonic.append(1);
  else:
    preds[i]=0
    Normal.append(1);

print(len(Pneumonic))
print(len(Normal))
# Out:
# 223
# 401

# %%
print(classification_report(y_test, preds, target_names = ['Pneumonic' , 'Normal']))
# Out:
#               precision    recall  f1-score   support
#
#    Pneumonic       0.92      0.94      0.93       390
#       Normal       0.90      0.85      0.88       234
#
#     accuracy                           0.91       624
#    macro avg       0.91      0.90      0.90       624
# weighted avg       0.91      0.91      0.91       624

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

preds = model.predict(x_test)

accuracy = accuracy_score(y_test, np.round(preds))
confusionMatrix = confusion_matrix(y_test, np.round(preds))

tn , fp , fn , tp = confusionMatrix.ravel()

print('\nConfusion Matrix ')
print(confusionMatrix)

print('\nTest Metrics ')
precision = tp/(tp+fp);
recall = tp/(tp+fn)
sensitivity = tn/(tn+fp)

print('Accuracy: {}'.format(accuracy))
print('Precision: {}'.format(precision))
print('Recall: {}'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(recall+precision)))

print('\nTrain Metric')
print('Train acc: {} %'.format(np.round((r.history['accuracy'][-1])*100,2)))
# Out:
# Confusion Matrix
# [[367  23]
#  [ 34 200]]
#
# Test Metrics
# Accuracy: 0.9086538461538461
# Precision: 0.8968609865470852
# Recall: 0.8547008547008547
# F1-score: 0.87527352297593
#
# Train Metric
# Train acc: 96.4 %

# %%
cm = pd.DataFrame(confusionMatrix , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <AxesSubplot:>
